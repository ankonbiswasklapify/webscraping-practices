# %%
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from random import randint
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
service = Service() # this is the important line of code!

options= webdriver.ChromeOptions()

# Going undercover:
# option.add_argument("--incognito")
# options.add_argument("--headless")

paginaton_url = 'https://www.bcsstudy.com/test/43th-bcs-model-test-1/'

start = time.time()

driver = webdriver.Chrome(service=service, options=options)

driver.get(paginaton_url)

#text_field = driver.find_element("id", "watuTakerEmail")
#text_field.send_keys("a@b.c")

button = driver.find_element("id", "action-button")
button.click()

print('here')
html = driver.page_source
soup = bs4.BeautifulSoup(html)

output = []

question_div = soup.find_all("div", {"class": "show-question"})
for question_sections in question_div:
    question = question_sections.find("div", {"class": "show-question-content"})
    question = question.text.lstrip().rstrip()
    print(question)
    count = 0
    
    answers = question_sections.find_all("li", {"class": "answer"})
    for answer in answers:
        answer = answer.text.lstrip().rstrip()
        print('----->',answer)
        count=count+1
        if count==1:
            answer1 = answer
            
        if count==2:
            answer2 = answer
            
        if count==3:
            answer3 = answer
            
        if count==4:
            answer4 = answer
        
    correct_answer = question_sections.find("li", {"class": "correct-answer"})
    
    correct_answer = correct_answer.text.lstrip().rstrip() if correct_answer else ''
    print(type(correct_answer))
    print(correct_answer)
    
    output.append({
                    'question' : question,
                    'answer 1': answer1,
                    'answer 2' : answer2,
                    'answer 3': answer3,
                    'answer 4': answer4,
                    'correct_answer': correct_answer
                })
#print(question_div)
print(output)
driver.quit() # Closing the browser we opened

# %%
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from random import randint
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import bs4
service = Service() # this is the important line of code!

options= webdriver.ChromeOptions()

# Going undercover:
# option.add_argument("--incognito")
# options.add_argument("--headless")

paginaton_url = 'https://uttoron.academy/question/45th-bcs/'

start = time.time()

driver = webdriver.Chrome(service=service, options=options)

driver.get(paginaton_url)

html = driver.page_source
soup = bs4.BeautifulSoup(html)

output = []

question_div = soup.find_all("div", {"class": "question-item"})
for question_sections in question_div:
    question = question_sections.find("div", {"class": "question"}).find("p")
    question = question.text.lstrip().rstrip().replace("\n", "")
    print(question)
    count = 0
    
    answers = question_sections.find("div", {"class": "options"}).find_all("li")
    for answer in answers:
        answer = answer.find_all("span")[1]
        answer = answer.text.lstrip().rstrip().replace("\n", "")
        print(answer)
        count=count+1
        if count==1:
            answer1 = answer
            
        if count==2:
            answer2 = answer
            
        if count==3:
            answer3 = answer
            
        if count==4:
            answer4 = answer
        
    right_answer = question_sections.find("li", {"class": "is_right"})
    if right_answer:
        right_answer = right_answer.find_all("span")[1]
        right_answer = right_answer.text.lstrip().rstrip().replace("\n", "") if right_answer else ''
        print("---->",right_answer)
    else:
        right_answer = ""
    
    output.append({
                    'question' : question,
                    'answer 1': answer1,
                    'answer 2' : answer2,
                    'answer 3': answer3,
                    'answer 4': answer4,
                    'correct_answer': right_answer
                })
    
print(output)
driver.quit()
# Out:
# She insisted on ––– leaving the house.
# he
# him
# himself
# his
# ----> his
# The phrase “Achilles’ heel” means––
# a strong point
# a strong solution
# a weak point
# a permanent solution
# ----> a weak point
# He does not adhere ––– any principle.
# by
# in
# at
# to
# ----> to
# Millennium is a period of–––
# 100 year
# 1000 year
# 1 million year
# 1 million year
# ----> 1000 year
# Identify the passive form of the following sentence : Who has broken this jug?
# By whom has this jug been broken?
# By whom has this jug broken?
# By whom this jug has been broken?
# Whom has this gug been broken?
# ----> By whom has this jug been broken?
# Who is not a Victorian poet?
# Alfred Tennyson
# Robert Browning
# William Wordsworth
# Matthew Arnold
# ----> William Wordsworth
# Which of the following novels was written by George Orwell?
# 1984―
# Brave New World―
# A clockwork Orange―
# For Whom the Bell Tolls―
# ----> 1984―
# Identify the correct sentence:
# She speaks English like English
# She speaks the English like English
# She speaks the English like the English
# She speaks English like the English
# ----> She speaks English like the English
# When one makes a promise, one must not go ––– on it.
# forward
# back
# by
# around
# ----> back
# I can′t put up with― him any more. Here “put up with” means:
# To protect
# To terminate
# To tolerate
# To prevent
# ----> To tolerate
# The poem “To his Coy Mistress” Was written by:
# Andrew Marvell
# John Donne
# George Herbert
# Henry Vaughan
# ----> Andrew Marvell
# The synonyms of ‘altitude’ is–––
# height
# width
# length
# depth
# ----> height
# The character, Elizabeth Bennett, appears in the novel––
# Pride and Prejudice―
# Tess of the D′llrberville―
# Wuthering Heights―
# Jane Eyre―
# ----> Pride and Prejudice―
# This could have worked if I ____ been more far- sighted.
# have
# had
# might
# would
# ----> had
# What may be considered courteous in one culture may be−arrogant― inanother. Here the underlined word “arrogant” means–––
# rude
# gracious
# coarse
# pretentious
# ----> rude
# Don Juan― was composed by–––
# W B Yeats
# E.B. Browning
# George Gordon Byron
# Alexander Pope
# ----> George Gordon Byron
# Identify the imperative sentence:
# Shut up!
# Shahin is playing football.
# I shall cook dinner now.
# What is your name?
# ----> Shut up!
# “Black Death” is the name of a ––
# fever
# black fever
# plague pandemic
# death of black people
# ----> plague pandemic
# ‘Ulysses is a poem written by––
# Robert Browning
# Wordsworth
# S.T. Coleridge
# Alfred Tennyson
# ----> Alfred Tennyson
# Who wrote the poem ‘Ozymandias’?
# Thomas Hardy
# Robert Frost
# P.B Shelley
# Edmund Spenser
# ----> P.B Shelley
# Clym Yeobringht is the protagonist of the novel––
# David Copperfield
# Adam Bede
# A passage of India
# The Return of the Native
# ----> The Return of the Native
# The train is running ––– forty miles an hour.
# on
# to
# at
# for
# ----> at
# He divided the money ––– the two children.
# between
# over
# among
# in between
# ----> between
# No one can ––– that he is clever.
# defy
# deny
# admire
# denounce
# ----> deny
# Choose the right form of verb: The boy (to lie) on the floor yesterday.
# lies
# lied
# lay
# layed
# ----> lay
# She played on the flute. Passive form is –––
# The flute was played by ger.
# The flute was played on by her.
# The flute was played to her.
# The flute was being played by her.
# ----> The flute was played on by her.
# Antonym for Adieu–––
# Farewell
# Good bye
# Hello
# Valediction
# ----> Hello
# ‘Walk fast lest you should miss the train’. This is a––
# Simple sentence
# Compound sentence
# Complex sentence
# Interrogative sentence
# ----> Complex sentence
# A number of singers in a church is called––
# Choir
# Cast
# Claque
# Clump
# ----> Choir
# Put the right word in the blank. “He reached the ––– of his literary carrer.”
# abattoir
# acme
# admonish
# abdicate
# ----> acme
# Anger may be compared ––– fire.
# to
# within
# against
# into
# ----> to
# Choose the correct sentence:
# He discussed the matter.
# He discussed about the mater.
# He discussed on the matter.
# None of the above.
# ----> He discussed the matter.
# Identify the correct spelt word.
# Horroscope
# Pneumonia
# Occasion
# Embarass
# ----> Pneumonia
# Desdemona is a character in the following Shakespearean play:
# Macbeth
# Othello
# Hamlet
# King Lear
# ----> Othello
# Meteorology is related to––
# concrete slabs
# motor vehicles
# weather forecasting
# motor neurone disease
# ----> weather forecasting
# ‘ধ্বনি’ সম্পর্কে নিচের কোন বাক্যটি সঠিক নয়?
# ধ্বনি দৃশ্যমান
# মানুষের ভাষার মূলে আছে কতগুলো ধ্বনি
# ধ্বনি উচ্চারণীয় ও শ্রবণীয়
# অর্থবোধক ধ্বনিগুলোই মানুষের বিভিন্ন ভাষার বাগ্‌ধ্বনি
# ----> ধ্বনি দৃশ্যমান
# স্বরাস্ত অক্ষরকে কী বলে?
# একাক্ষর
# মুক্তাক্ষর
# বদ্ধাক্ষর
# যুক্ষাক্তর
# ----> মুক্তাক্ষর
# শুদ্ধ বানানের গুচ্ছ কোনটি?
# শিরশ্ছেদ, দরিদ্রতা, সমীচীন
# শিরোশ্ছেদ, দারিদ্র, সমীচিন
# শিরঃশ্ছেদ, দরিদ্রতা, সমিচীন
# শিরচ্ছেদ, দরিদ্রতা, সমীচীন
# ----> শিরশ্ছেদ, দরিদ্রতা, সমীচীন
# আরবি ‘কলম’ শব্দটি ‘কলমোস’ শব্দ থেকে এসেছে। ‘কলমোস’ কোন ভাষার শব্দ?
# পাঞ্জাবি
# ফরাসি
# গ্রিক
# স্পেনিশ
# ----> গ্রিক
# ‘ভাষা চিন্তার শুধু বাহনই নয়, চিন্তার প্রসূতিও’। মন্তব্যটি কোন ভাষা-চিন্তকের?
# সুনীতিকুমার চট্টোপাধ্যায়
# মুহম্মদ শহীদুল্লাহ
# মুহম্মদ এনামুল হক
# সুকুমার সেন
# ----> সুকুমার সেন
# সর্বপ্রথম বাংলা ভাষার ব্যাকরণ রচনা করেন কে?
# মানোএল দ্য আস্‌সুম্পসাঁও
# রাজা রামমোহন রায়
# রামেন্দ্র সুন্দর ত্রিবেদী
# নাথানিয়েল ব্রাসি হ্যালহেড
# ----> মানোএল দ্য আস্‌সুম্পসাঁও
# উচ্চারণের রীতি অনুযায়ী নিচের কোনটি উচ্চমধ্য-সম্মুখ স্বরধ্বনি?
# অ
# আ
# ও
# এ
# ----> এ
# ‘তাম্বুলিক’ শব্দের সমার্থক নয় কোনটি?
# পান-ব্যবসায়ী
# পর্ণকার
# তামসিক
# বারুই
# ----> তামসিক
# ‘তুমি তো ভারি সুন্দর ছবি আঁক।’– বাক্যটিতে কোন প্রকারের অব্যয় পদ ব্যবহৃত হয়েছে?
# পদান্বয়ী অব্যয়
# অনুসর্গ অব্যয়
# অনন্বয়ী অব্যয়
# অনুকার অব্যয়
# ----> অনন্বয়ী অব্যয়
# নিচের কোনটি যৌগিক শব্দ?
# প্রবীণ
# জেঠামি
# সরোজ
# মিতালি
# ----> মিতালি
# ‘সুনামীর তান্ডবে অনেকেই সর্বশান্ত হয়েছে।’– বাক্যটিতে কয়টি ভুল আছে?
# একটি
# দুটি
# তিনটি
# ভুল নেই
# ----> তিনটি
# কৃদন্ত পদের পূর্ববর্তী পদকে কী বলে?
# উপপদ
# প্রাতিপদিক
# প্রপদ
# পূর্বপদ
# ----> উপপদ
# ‘তোমার নাম কী?’– এখানে ‘কী’ কোন প্রকারের শব্দ?
# প্রশ্নবাচক
# অব্যয়
# সর্বনাম
# বিশেষণ
# ----> সর্বনাম
# ‘সরল’ শব্দের বিপরীতার্থক নয় নিচের কোনটি?
# কুটিল
# জটিল
# বক্র
# গরল
# ----> গরল
# ‘Rank’ শব্দের বাংলা পরিভাষা কী?
# পদ
# পদমর্যাদা
# মাত্রা
# উচ্চতা
# ----> পদমর্যাদা
# চর্যাপদের তিব্বতি অনুবাদ প্রকাশ করেন কে?
# প্রবোধচন্দ্র বাগচী
# যতীন্দ্র মোহন বাগচী
# প্রফুল্ল মোহন বাগচী
# প্রণয়ভূষণ বাগচী
# ----> প্রবোধচন্দ্র বাগচী
# ‘গীতগোবিন্দ’ কাব্যের রচয়িতা জয়দেব কার সভাকবি ছিলেন?
# শশাঙ্কদেবের
# লক্ষ্মণ সেনের
# যশোবর্মনের
# হর্ষবর্ধনের
# ----> লক্ষ্মণ সেনের
# কবি যশোরাজ খান বৈষ্ণবপদ রচনা করেন কোন ভাষায়?
# ব্রজবুলি
# বাংলা
# সংস্কৃত
# হিন্দি
# ----> ব্রজবুলি
# নিচের কোন জন যুদ্ধকাব্যের রচয়িতা নন?
# দৌলত উজির বাহরাম খাঁ
# সাবিরিদ খাঁ
# সৈয়দ সুলতান
# সৈয়দ নূরুদ্দীন
# ----> সৈয়দ নূরুদ্দীন
# কোনটি কবি জৈনুদ্দিনের কাব্যগ্রন্থ?
# রসুল বিজয়
# মক্কা বিজয়
# রসুলচরিত
# মক্কানামা
# ----> রসুল বিজয়
# “বিদ্যাসাগর ও বাঙালি সমাজ” গ্রন্হের রচয়িতা কে?
# বিনয় ঘোষ
# সুবিনয় ঘোষ
# বিনয় ভট্টাচার্য
# বিনয় বর্মণ
# ----> বিনয় ঘোষ
# প্রথম সাহিত্যিক গদ্যের স্রষ্টা কে?
# রাাজা রামমোহন রায়
# ঈশ্বরচন্দ্র বিদ্যাসাগর
# মৃত্যুঞ্জয় বিদ্যালঙ্কার
# বঙ্কিমচন্দ্র চট্টোপাধ্যায়
# ----> ঈশ্বরচন্দ্র বিদ্যাসাগর
# প্যারীচাঁদ মিত্রের ‘আলালের ঘরের দুলাল’ প্রথম গ্রন্হাকারে প্রকাশিত হয় কত সালে?
# ১৮৫৮ সালে
# ১৯৭৮ সালে
# ১৮৪৮ সালে
# ১৮৬৮ সালে
# ----> ১৮৫৮ সালে
# শচীন, দামিনী ও শ্রীবিলাস রবীন্দ্রনাথ ঠাকুরের কোন উপন্যাসের চরিত্র?
# চতুরঙ্গ
# চার অধ্যায়
# নৌকাডুবি
# ঘরে বাইরে
# ----> চতুরঙ্গ
# ‘তুমি মা কল্পতরু আমরা সব পোষাগরু’– এই কবিতাংশটির রচয়িতা কে?
# রঙ্গলাল বন্দ্যোপাধ্যায়
# ঈশ্বরচন্দ্র বিদ্যাসাগর
# হেমচন্দ্র বন্দ্যোপাধ্যায়
# ঈশ্বরচন্দ্র গুপ্ত
# ----> ঈশ্বরচন্দ্র গুপ্ত
# মীর মশাররফ হোসেনের কোন গ্রন্হের উপজীব্য হিন্দু মুসলমানের বিরোধ?
# গো-জীবন
# ইসলামের জয়
# এর উপায় কী
# বসন্তকুমারী নাটক
# ----> গো-জীবন
# রবীন্দ্রনাথ ঠাকুর কত বয়সে ছোটগল্পকার হিসেবে আত্মপ্রকাশ করেন?
# ১০ বছর
# ১২ বছর
# ১৪ বছর
# ১৬ বছর
# ----> ১৬ বছর
# নিচের কোনটি বিভূতিভূষণ বন্দ্যোপাধ্যায়ের গল্পগ্রন্থ নয়?
# ইছামতি
# মেঘমল্লার
# মৌরিফুল
# যাত্রাবদল
# ----> ইছামতি
# ‘আমার পথ’ প্রবন্ধটি কাজী নজরুল ইসলামের কোন গ্রন্থ থেকে সংকলিত হয়েছে?
# যুগ-বাণী
# রুদ্র-মঙ্গল
# দুর্দিনের যাত্রী
# রাজবন্দির জবানবন্দি
# ----> রুদ্র-মঙ্গল
# ‘জীবন ও বৃক্ষ’ প্রবন্ধে মোতাহের হোসেন চৌধুরী কাকে তপোবন-প্রেমিক বলেছেন?
# বিভূতিভূষণ বন্দ্যোপাধ্যায়কে
# জসীম উদ্দীনকে
# রবীন্দ্রনাথ ঠাকুরকে
# শরৎচন্দ্র চট্টোপাধ্যায়কে
# ----> রবীন্দ্রনাথ ঠাকুরকে
# ‘আমি যখন জেলে যাই তখন ওর বয়স মাত্র কয়েক মাস’– এখানে ‘ওর’ বলতে শেখ মুজিবুর রহমান কাকে বুঝিয়েছেন?
# শেখ নাসেরকে
# শেখ কামালকে
# শেখ হাসিনাকে
# শেখ রেহানাকে
# ----> শেখ কামালকে
# আখতারুজ্জামান ইলিয়াস জন্মগ্রহণ করেন কোথায়?
# গাইবান্ধায়
# বগুড়ায়
# ঢাকায়
# সিরাজগঞ্জে
# ----> গাইবান্ধায়
# মাইকেল মধুসূদন দত্ত প্রবর্তিত ‘অমিত্রাক্ষর ছন্দ’ প্রকৃত পক্ষে বাংলা কোন ছন্দের নব-রুপায়ন?
# স্বরবৃত্ত ছন্দ
# অক্ষরবৃত্ত ছন্দ
# মাত্রাবৃত্ত ছন্দ
# গৈরিশ ছন্দ
# ----> অক্ষরবৃত্ত ছন্দ
# ‘বুক তার বাংলাদেশের হৃদয়’ কাব্যগ্রন্থের রচয়িতা কে?
# সৈয়দ শামসুল হক
# শামসুর রাহমান
# হাসান হাফিজুর রহমান
# আহসান হাবিব
# ----> শামসুর রাহমান
# “দুর্দিনের দিনলিপি” স্মৃতিগ্রন্থটি কার লেখা?
# আবুল ফজল
# আবদুল কাদির
# জাহানারা ইমাম
# মুশতারি শফী
# ----> আবুল ফজল
# বাংলাদেশ সদস্য নয় :
# ILO
# SAARC
# NATO
# BIMSTEC
# ----> NATO
# ফিফা বিশ্বকাপ ফুটবল কখন প্রথম অনুষ্ঠিত হয়?
# ১৯২৯
# ১৯৩০
# ১৯৩১
# ১৯৩২
# ----> ১৯৩০
# কোন দেশে সমুদ্র বন্দর নাই?
# মালদ্বীপ
# নেপাল
# গ্রীস
# ভেনেজুয়েলা
# ----> নেপাল
# কোথায় ঐতিহাসিক ট্রয় নগর অবস্থিত?
# ইটালী
# গ্রীস
# তুরস্ক
# ফ্রান্স
# ----> তুরস্ক
# ক্ষুদ্রতম মহাদেশ :
# অস্ট্রেলিয়া
# ইউরোপ
# আফ্রিকা
# দক্ষিণ আমেরিকা
# ----> অস্ট্রেলিয়া
# কোথায় আন্তর্জাতিক ধান গবেষণা ইনস্টিটিউট অবস্থিত?
# টোকিও
# ম্যানিলা
# ভারত
# নেপাল
# ----> ম্যানিলা
# কোথায় ইউরোপীয় কেন্দ্রীয় ব্যাংক অবস্থিত?
# লন্ডন
# প্যারিস
# ব্রাসেলস
# ফ্রাঙ্কফুর্ট
# ----> ফ্রাঙ্কফুর্ট
# যুক্তরাষ্ট্রের ৪৫তম প্রেসিডেন্ট কে ছিলেন?
# রিচার্ড নিক্সন
# বিল ক্লিনটন
# কেনেডি
# ডনাল্ড ট্রাম্প
# ----> ডনাল্ড ট্রাম্প
# TIFA এর পূর্ণরূপ কী?
# Trade for International Finance Agreement.
# Trade and Investment Framework Agreement
# Treaty for International Free Area
# Trade and Inviestment form America
# ----> Trade and Investment Framework Agreement
# ভারত কর্তৃক সিকিম সংযুক্ত হয়-
# ১৯৭০
# ১৯৭২
# ১৯৭৫
# ১৯৭৭
# ----> ১৯৭৫
# ২০২২ সালে G-20 শীর্ষ বৈঠক কোথায় অনুষ্ঠিত হয়?
# সিংগাপুর
# জাকার্তা
# ম্যানিলা
# বালী
# ----> বালী
# চীন-ভারত যুদ্ধ কত সালে সংঘটিত হয়?
# ১৯৫৯
# ১৯৬০
# ১৯৬২
# ১৯৬৩
# ----> ১৯৬২
# পৃথিবীর গভীরতম স্থান:
# ম্যারিয়ানা ট্রেন্চ
# ডেড সী
# বৈকাল হ্রদ
# লোহিত সাগর
# ----> ম্যারিয়ানা ট্রেন্চ
# ‘বেল্ট অ্যান্ড রোড’ কার্যক্রম শুরু হয়:
# ২০০০ সাল
# ২০০১ সাল
# ২০১৩ সাল
# ২০১৬ সাল
# ----> ২০১৩ সাল
# বান্দা আচেহ কোথায় অবস্থিত?
# ইন্দোনেশিয়া
# থাইল্যান্ড
# ফিলিপাইন
# কম্বোডিয়া
# ----> ইন্দোনেশিয়া
# ফেসবুকের সদর দফতর :
# সিয়াটল
# ক্যালিফোর্নিয়া
# ওয়াশিংটন
# নিউইয়র্ক
# ----> ক্যালিফোর্নিয়া
# ‘ভিক্টোরিয়া ডিজার্ট’ কোথায় অবস্থিত?
# কানাডা
# পশ্চিম আফ্রিকা
# নর্থ আমেরিকা
# অস্ট্রেলিয়া
# ----> অস্ট্রেলিয়া
# কোনটি প্রাচীন সভ্যতা?
# গ্রিস
# মেসোপটেমিয়া
# রোম
# সিন্ধু
# ----> মেসোপটেমিয়া
# তিব্বত একটি-
# উপত্যকা
# উপদ্বীপ
# দ্বীপ
# মরুভুমি
# ----> উপত্যকা
# ‘Elephant Pass’ অবস্থিত?
# থাইল্যান্ড
# দক্ষিণ আফ্রিকা
# শ্রীলঙ্কা
# মালয়শিয়া
# ----> শ্রীলঙ্কা
# কোন দেশটি ইউরোপীয় ইউনিয়নের সদস্য নয়?
# সাইপ্রাস
# আলজেরিয়া
# ইস্টোনিয়া
# মাল্টা
# ----> আলজেরিয়া
# কোন নদীটির উৎপত্তিস্থান বাংলাদেশে?
# কর্ণফুলি
# নাফ
# মেঘনা
# হালদা
# ----> হালদা
# পানিতে দ্রবীভূত অক্সিজেন কোথায় অবস্থান করে?
# পানির উপরিভাগে
# পানির মধ্যভাগে
# পানির আন্তঃআণবিক স্থানে
# পানির তলদেশে
# ----> পানির আন্তঃআণবিক স্থানে
# গ্রীন হাউস গ্যাসের কোন গ্যাস বর্তমানে বৃদ্ধি পাচ্ছে না?
# কার্বন ডাইঅক্সাইড
# মিথেন
# সিএফসি
# নাইট্রাস অক্সাইড
# ----> সিএফসি
# বাংলাদেশে সিডর কখন আঘাত হানে?
# ১৫ নভেম্বর ২০০৭
# ১৬ নভেম্বর ২০০৭
# ১৭ নভেম্বর ২০০৭
# ১৮ নভেম্বর ২০০৭
# ----> ১৫ নভেম্বর ২০০৭
# বাংলাদেশের অর্থনৈতিক সমুদ্রসীমা কত নটিক্যাল মাইল?
# ১৫০ নটিক্যাল মাইল
# ২০০ নটিক্যাল মাইল
# ২৫০ নটিক্যাল মাইল
# ৩০০ নটিক্যাল মাইল
# ----> ২০০ নটিক্যাল মাইল
# নিচের কোনটি বাংলাদেশের সর্ববৃহৎ গ্যাস ক্ষেত্র?
# বাখরাবাদ
# হরিপুর
# তিতাস
# হবিগঞ্জ
# ----> তিতাস
# ভূমিকম্প সংঘটন বিন্দুর সরাসরি উপরে ভূপৃষ্ঠস্থ বিন্দুকে বলে –
# ফোকাস
# এপিসেন্টার
# ফ্রাকচার
# ফল্ট
# ----> এপিসেন্টার
# বিশ্বব্যাপী নিচের কোন অর্থনৈতিক খাত থেকে সবচাইতে বেশি গ্রিন হাউজ গ্যাস নির্গত হয়?
# পরিবহন
# বিদ্যুৎ ও তাপ উৎপাদন
# ভবন নির্মাণ
# শিল্প
# ----> বিদ্যুৎ ও তাপ উৎপাদন
# উত্তর গোলার্ধে ক্রান্তীয় ঘূর্ণিঝড়ের বায়ু প্রবাহিত হয়-
# ঘড়ির কাটার দিকে
# ঘড়ির কাটার বিপরীতে
# সোজা
# কোনটাই সঠিক নয়
# ----> ঘড়ির কাটার বিপরীতে
# (x2y+xy2 এবং x2+xy রাশিদ্বয়ের ল.সা.গু. এবং গ.সা.গু. এর গুণফল কত?
# x2y2(x+y)
# xy(x2+y2)
# x2y(x+y)2
# xy2(x2+y)
# ----> x2y(x+y)2
# যদি ∶∶x∶y=2∶3 এবং ∶∶y∶z=5∶7 হয়, তবে ∶∶x∶y∶z=?
# 6 : 9 : 14
# 10 : 15 : 21
# 2 : 5 : 7
# 3 : 5 : 7
# ----> 10 : 15 : 21
# জাহিদ সাহেবের বেতন 10% কমানোর পর হ্রাসকৃত বেতন 10% বাড়ানো হলে তার কতটুকু ক্ষতি হল?
# 0%
# 1%
# 5%
# 10%
# ----> 1%
# (x+5)2=x2+bx+c সমীকরণে b ও c এর মান কত হলে সমীকরণটি অভেদ হবে?
# 3,10
# 10,15
# 15, 25
# 10, 25
# ----> 10, 25
# নিচের কোনটি সরলরেখার সমীকরণ?
# xy= y2
# x2+y=1
# xy= 12
# x= 1y
# ----> xy= 12
# p+q=5 এবং p−q=3 হলে p2+q2 এর মান কত?
# 8
# 17
# 19
# 34
# ----> 17
# যদি  log⁡(ab)+ log⁡(ba)=log⁡(a+b) হয়, তবে-
# a+b=1
# a−b=1
# a=b
# a2−b2=1
# ----> a+b=1
# 2x+7=4x+2 হলে x এর মান কত?
# 2
# 3
# 4
# 6
# ----> 3
# 13,-1,3,….. ধারাটির পঞ্চম পদ কত?
# −3
# 9
# −93
# 33
# ----> 33
# যদি θ1+tan2⁡θ=4 এবং θ<90° হয়, θ=?
# 30∘
# 45∘
# 60∘
# 0∘
# ----> 60∘
# একটি বৃত্তচাপ কেন্দ্রে 60∘ কোণ উৎপন্ন করে। বৃত্তের ব্যাস 12cm হলে বৃত্তচাপের দৈর্ঘ্য কত?
# 4π
# 3π
# 2π
# π
# ----> 2π
# একটি ত্রিভুজের বাহুগুলোর অনুপাত 1:22:3 হলে এর বৃহত্তম কোণটির মান কত?
# 30∘
# 60∘
# 80∘
# 90∘
# ----> 90∘
# 29 থেকে 38 পর্যন্ত সংখ্যা হতে যে কোনো একটিকে ইচ্ছামত বেছে নিলে সেটি মৌলিক হওয়ার সম্ভাবনা কত?
# 12
# 13
# 310
# 710
# ----> 310
# 0, 1, 2, 3, 4 অংকগুলি দ্বারা কতগুলি পাঁচ অংকের অর্থপূর্ণ সংখ্যা গঠন করা যাবে?
# 96
# 120
# 24
# 144
# ----> 96
# A={x∈N:x2−5x−14=0} হলে, A=?
# 6,1
# −2,7
# 2,7
# 7
# ----> 7
# কোন সংখ্যাটি পরে আসবে? ৮ ৪ ২ ১৮ ৪ ২ ১ ১২১২ ১৪১৪
# ১৮১৮
# ১৪১৪
# ১৫১৫
# ১৬১৬
# ----> ১৮১৮
# কাগজের প্রতি পাতা বিক্রি হয় ২১ পয়সায়। চার পাতা কত পয়সায় বিক্রি হবে?
# ৪ পয়সা
# ৯৪ পয়সা
# ৮ পয়সা
# ৮৪ পয়সা
# ----> ৮৪ পয়সা
# মনে কর প্রথম দুটি উক্তি সত্য। তবে শেষের উক্তিটি-
# সত্য
# মিথ্যা
# অনিশ্চিত
# আংশিক সত্য
# ----> অনিশ্চিত
# কোন সংখ্যাটি নিম্নের শ্রেণিতে সবচাইতে স্বল্প পরিমাণ উপস্থাপন করে?
# ৭
# ৮
# .৩৩
# .৩১
# ----> .৩১
# যখন প্রতি ফুট দড়ি ১০ টাকায় বিক্রি হয়, তখন ৬০ টাকায় তুমি কত ফুট দড়ি ক্রয় করতে পারবে?
# ৮ ফুট
# ৭ ফুট
# ৬ ফুট
# ১০ ফুট
# ----> ৬ ফুট
# কোনটি ভারসাম্যপূর্ণ অবস্থা?
#
#
#
#
# ---->
# নিম্নলিখিত সংখ্যা শ্রেণির সর্বশেষ সংখ্যার পরের সংখ্যাটি কত হবে? ১ ২ ৪ ৭ ১১ ?
# ১৪
# ১৫
# ১৬
# ১৮
# ----> ১৬
#
# ১
# ৩
# ২
# ৪
# ----> ৪
# নোবেল বিজয়ী নারী কয়জন?
# ৫০ জন
# ৫৭ জন
# ০৩ জন
# ০৭ জন
# ----> ৫৭ জন
# যদি চ ৪২×G=৪২ হয় তবে J× ট = ?
# ১২০
# ৯২
# ১১৫
# ১১০
# ----> ১১০
# ROSE এর আয়নায় প্রতিবিম্ব কোনটি হবে?
#
#
#
# কোনোটিই নয়
# ---->
#
#
#
#
#
# ---->
# একটি ট্রেন ১৫১৫ সেকেন্ডে চলে ২০২০ ফুট। একই দ্রুততায় ট্রেনটি ৩৩ সেকেন্ডে কত ফুট চলবে?
# ১০০ ফুট
# ১১০ ফুট
# ৩০০ ফুট
# কোনোটিই নয়
# ----> ৩০০ ফুট
# যাদের বুদ্ধ্যঙ্ক ১৪০ বা তার ঊর্ধ্বে তাদের বলা হয়-
# অতিশয় প্রতিভাশালী
# প্রতিভাশালী
# সাধারণ
# মানসিক প্রতিবন্ধী
# ----> অতিশয় প্রতিভাশালী
# RESENT, RESERVE- এই শব্দগুলো কী?
# একই অর্থে
# বিপরীতধর্মী অর্থ
# না এক না ভিন্ন অর্থ
# কোনোটিই নয়
# ----> না এক না ভিন্ন অর্থ
# ভালো-মন্দ কোন ধরনের মূল্যবোধ?
# নৈতিক
# অর্থনৈতিক
# রাজনৈতিক
# সামাজিক
# ----> নৈতিক
# সুশাসনের পূর্বশর্ত কী?
# নিরপেক্ষ আইন ব্যবস্থা
# নিরপেক্ষ বিচার ব্যবস্থা
# প্রশাসনের নিরপেক্ষতা
# মত প্রকাশের স্বাধীনতা
# ----> মত প্রকাশের স্বাধীনতা
# ‘Utilitarianism’ গ্রন্হের লেখক কে?
# জন স্টুয়ার্ট মিল
# ইমানুয়েল কান্ট
# বার্ট্রান্ড রাসেল
# জেরেমি বেন্হাম
# ----> জন স্টুয়ার্ট মিল
# সুশাসন প্রত্যয়টির উদ্ভাবক কে?
# ইউরোপীয় ইউনিয়ন
# আই. এল. ও
# বিশ্বব্যাংক
# জাতিসংঘ
# ----> বিশ্বব্যাংক
# সহস্রাব্দ উন্নয়ন লক্ষ্য অর্জনে সুশাসনের কোন দিকটির উপর গুরুত্ব দেওয়া হয়েছে?
# সামাজিক দিক
# অর্থনৈতিক দিক
# মূল্যবোধের দিক
# গণতান্ত্রিক দিক
# ----> অর্থনৈতিক দিক
# ‘জ্ঞান হয়ে পুণ্য’- এই উক্তিটি কার?
# থেলিস
# সক্রেটিস
# এ্যারিস্টটল
# প্লেটো
# ----> সক্রেটিস
# নৈতিকতা ও সততা দ্বারা প্রভাবিত আচরণগত উৎকর্ষকে কী বলে?
# শুদ্ধাচার
# মূল্যবোধ
# মানবিকতা
# সফলতা
# ----> শুদ্ধাচার
# মূল্যবোধের উৎস কোনটি?
# ধর্ম
# সমাজ
# নৈতিক চেতনা
# রাষ্ট্র
# ----> নৈতিক চেতনা
# ‘শর্তহীন আদেশ’ ধারণাটির প্রবর্তক কে?
# অ্যারিস্টটল
# বার্ট্রান্ড রাসেন
# হার্বাট স্পেন্সার
# ইমানুয়েল কান্ট
# ----> ইমানুয়েল কান্ট
# সুশাসনের মূলভিত্তি-
# গণতন্ত্র
# আমলাতন্ত্র
# আইনের শাসন
# মূল্যবোধ
# ----> আইনের শাসন
# নিচের কোনটি চার্লসের সূত্র?
# V∝T
# PV=K
# V∝n
# P∝T
# ----> V∝T
# সোডিয়াম ক্লোরাইড (NaCl) কেলাসের গঠন কীরূপ?
# পৃষ্ঠতল কেন্দ্রিক ঘনকাকৃতির
# দেহ-কেন্দ্রিক ঘনকাকার
# সংঘবদ্ধ-ঘনকাকার
# সংঘবদ্ধ ষড়কৌণিক আকার
# ----> পৃষ্ঠতল কেন্দ্রিক ঘনকাকৃতির
# নিচের কোনটি প্রাইমারি দূষক?
# SO3
# N2O5
# NO
# HNO3
# ----> NO
# HPLC এর পূর্ণরূপ কী?
# High pressure liquid chromatography
# High power liquid chromatography
# High plant liquid chromatography
# High performance liquid chromatography
# ----> High performance liquid chromatography
# নিচের কোনটি সিরামিক উপাদানের প্রধান কাঁচামাল?
# SiO2
# Na2CO3
# Fe2O3
# NaNO3
# ----> SiO2
# সানস্ক্রিন লোশন তৈরিতে কোন ন্যানো পার্টিকেল ব্যবহৃত হয়?
# Na2O
# ZnO
# Al2O3
# CuO
# ----> ZnO
# মানুষের দেহকোষে ক্রোমোজমের সংখ্যা-
# ৪৪টি
# ৪২টি
# ৪৬টি
# ৪৮টি
# ----> ৪৬টি
# সুষম খাদ্যে শর্করা, আমিষ ও চর্বিজাতীয় খাদ্যের অনুপাত?
# ৪ : ১ : ১
# ৪ : ২ : ২
# ৪ : ২ : ৩
# ৪ : ৩ : ২
# ----> ৪ : ১ : ১
# মানুষের শরীরের রক্তের গ্রুপ কয়টি?
# চারটি
# পাঁচটি
# তিনটি
# দুইটি
# ----> চারটি
# আর্সেনিকের পারমাণবিক সংখ্যা কত?
# ৩৩
# ৩৮
# ৩৬
# ৪৪
# ----> ৩৩
# উড়োজাহাজের গতি নির্ণায়ক যন্ত্রের নাম কী?
# ট্যাকোমিটার
# অ্যালটিমিটার
# ওডোমিটার
# অডিওমিটার
# ----> ট্যাকোমিটার
# টেলিভিশনে যে তরঙ্গ ব্যবহৃত হয় –
# রেডিও ওয়েভ
# অবলোহিত রশ্মি
# আলট্রা ভায়োলেট
# দৃশ্যমান রশ্মি
# ----> রেডিও ওয়েভ
# অণুজীব বিজ্ঞানের জনক কে?
# রবার্ট কক্‌
# লুইস পাস্তুর
# এডওয়ার্ড জেনার
# এন্টনি ভন লিউয়েনহুক
# ----> এন্টনি ভন লিউয়েনহুক
# বাতাস একটি -
# ডায়াচুম্বকীয় পদার্থ
# প্যারাচুম্বকীয় পদার্থ
# ফেরোচুম্বকীয় পদার্থ
# অ্যান্টিফেরোচুম্বকীয় পদার্থ
# ----> প্যারাচুম্বকীয় পদার্থ
# বিশ্ব ব্রহ্মাণ্ডের সবচেয়ে বেশি গ্যাসটি হল-
# অক্সিজেন
# কার্বন-ডাইঅক্সাইড
# নাইট্রোজেন
# হাইড্রোজেন
# ----> হাইড্রোজেন
# GPU -এর পূর্ণরূপ কী?
# Graph Processing Unit
# Graphic Processing Unit
# Graphics Processing Unit
# Geographical Processing Unit
# ----> Graphics Processing Unit
# নিচের কোনটি ALU -এর আউটপুট রাখার জন্য ব্যবহৃত হয়?
# Register
# ROM
# Flags
# Output Unit
# ----> Register
# DBMS -এর পূর্ণরূপ কী?
# Data Backup Management System
# Database Management Service
# Database Management System
# Data of Binary Mangement System
# ----> Database Management System
# 2 কিলোবাইট মেমোরি address করার জন্য কতটি address লাইন দরকার?
# 10
# 11
# 12
# 14
# ----> 11
# (2FA)16 এই হেক্সাডেসিমেল সংখ্যাটিকে অক্টালে রূপান্তর করুন:
# (762)8
# (1372)8
# (228)8
# (1482)8
# ----> (1372)8
# এমবেডেড সিস্টেমে সাধারণত কোন ধরনের মেমোরি ব্যবহৃত হয়?
# RAM
# হার্ডডিস্ক ড্রাইভ
# ফ্লাশ মেমোরি
# অপটিক্যাল ডিস্ক ড্রাইভ
# ----> RAM
# নিচের কোনটি Spyware এর উদাহরণ?
# Key loggers
# Avast
# Norton
# Kasparasky
# ----> Key loggers
# IPv4 -এ নিচের কোনটি Google DNS Server এর IP Adders?
# 8.8.7.6
# 8.7.8.6
# 8.8.8.6
# 8.8.8.8
# ----> 8.8.8.8
# ফায়ারওয়ালের প্রাথমিক কাজ কী?
# সমস্ত আগত ট্রাফিক নেটওয়ার্কে ঢুকতে না দেওয়া।
# সমস্ত আগত ট্রাফিক নেটওয়ার্কে ঢুকার অনুমতি দেওয়া।
# আগত এবং বহির্গত নেটওয়ার্ক ট্রাফিক নিরীক্ষা এবং নিয়ন্ত্রণ করা।
# সমস্ত নেটওয়ার্ক ট্রাফিক এনক্রিপ্ট করা।
# ----> আগত এবং বহির্গত নেটওয়ার্ক ট্রাফিক নিরীক্ষা এবং নিয়ন্ত্রণ করা।
# ইন্টারনেটের মাধ্যমে তথ্য আদান-প্রদানের জন্য সর্বাধিক ব্যবহৃত প্রোটোকল কী?
# HTTP
# FTP
# DNS
# TCP/IP
# ----> TCP/IP
# নিচের কোনটি ক্লাউড কম্পিউটিং এর বৈশিষ্ট্য নয়?
# On-demand self service
# Broad network access
# Limited customization
# Physical ownership of servers
# ----> Physical ownership of servers
# একটি কম্পিউটার নেটওয়ার্কে একটি LAN -এর একাধিক ডিভাইসকে একটি WAN -এর সাথে সংযুক্ত করে এমন ডিভাইস কোনটি?
# রাউটার
# ওয়েব সার্ভার
# ব্রীজ
# হাব
# ----> রাউটার
# প্রতারণামূলকভাবে সংবেদনশীল তথ্য যেমন পাসওয়ার্ড ও ক্রেডিট কার্ড নম্বর অর্জন করার জন্য ইন্টারনেট ব্যবহার করার অনুশীলনকে কী বলা হয়?
# Phishing
# Spamming
# Ransom ware
# Sniffing
# ----> Phishing
# চিকিৎসা ক্ষেত্রে কম্পিউটার এর কাজ কোনটি?
# তথ্য সংরক্ষণ
# ইমেজ বিশ্লেষণ
# রোগী পর্যবেক্ষণ
# উপরের সবগুলো
# ----> উপরের সবগুলো
# নিচের কোনটি সার্বজনীন ডিজিটাল লজিক গেইট?
# XOR
# AND
# NOR
# OR
# ----> NOR
# ‘ভারত ছাড়’ আন্দোলন শুরু হয় -
# ১৯১৭ সালে
# ১৯২৭ সালে
# ১৯৩৭ সালে
# ১৯৪২ সালে
# ----> ১৯৪২ সালে
# ‘সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম কমিটি’ গঠিত হয়-
# ১৯৪৮ সালে
# ১৯৫০ সালে
# ১৯৫২ সালে
# ১৯৫৪ সালে
# ----> ১৯৫২ সালে
# বাংলাদেশের জাতীয় সংসদের অধিবেশন আহ্বান করেন কে?
# রাষ্ট্রপতি
# স্পীকার
# চীফ হুইপ
# প্রধানমন্ত্রী
# ----> রাষ্ট্রপতি
# ঐতিহাসিক ‘ছয়-দফা’ বঙ্গবন্ধু শেখ মুজিবুর রহমান আনুষ্ঠানিকভাবে ঘোষণা করেন-
# ৫ ফ্রেব্রুয়ারি ১৯৬৬
# ২৩ মার্চ ১৯৬৬
# ২৬ মার্চ ১৯৬৬
# ৩১ মার্চ ১৯৬৬
# ----> ২৩ মার্চ ১৯৬৬
# ‘পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ’ প্রতিষ্ঠকালীন সাধারণ সম্পাদক -
# শেখ মুজিবুর রহমান
# শামছুল হক
# আতাউর রহমান খান
# আবুল হাশিম
# ----> শামছুল হক
# ‘প্রজাতন্ত্রের রাষ্ট্রভাষা বাংলা’ কথাটি সংবিধানের কোন অনুচ্ছেদে বলা হয়েছে?
# অনুচ্ছেদ : ২
# অনুচ্ছেদ : ৩
# অনুচ্ছেদ : ৪
# অনুচ্ছেদ : ৫
# ----> অনুচ্ছেদ : ৩
# ঐতিহাসিক ৭ মার্চের ভাষণ সংবিধানের কোন তফসিলে আছে?
# চতুর্থ তফসিল
# পঞ্চম তফসিল
# ষষ্ঠ তফসিল
# সপ্তম তফসিল
# ----> পঞ্চম তফসিল
# বাংলাদেশের সংবিধান অনুযায়ী “কোর্ট অব রেকর্ড” হিসাবে গণ্য-
# লেবার কোর্ট
# জজ কোর্ট
# হাই কোর্ট
# সুপ্রীম কোর্ট
# ----> সুপ্রীম কোর্ট
# বাংলাদেশে মোট কতটি পঞ্চবার্ষিকী পরিকল্পনা গ্রহণ করা হয়েছে?
# ৬ (ছয়) টি
# ৭ (সাত) টি
# ৮ (আট) টি
# ৯ (নয়) টি
# ----> ৮ (আট) টি
# বাংলাদেশের কয়টি জেলার সাথে ‘সুন্দরবন’ সংযুক্ত আছে?
# ৪ (চার) টি
# ৫ (পাঁচ) টি
# ৬ (ছয়) টি
# ৭ (সাত) টি
# ----> ৫ (পাঁচ) টি
# মহান মুক্তিযুদ্ধের সময় ঢাকা শহর কোন সেক্টরের অন্তর্ভুক্ত ছিল?
# ২ (দুই) নম্বর
# ৩ (তিন) নম্বর
# ৪ (চার) নম্বর
# ৫ (পাঁচ) নম্বর
# ----> ২ (দুই) নম্বর
# ‘জয় বাংলা’ কে জাতীয় স্লোগান হিসাবে মন্ত্রিসভায় কত তারিখে অনুমোদন করা হয়?
# ২ মার্চ, ২০২২
# ৩ মার্চ, ২০২২
# ৪ মার্চ, ২০২২
# ৫ মার্চ, ২০২২
# ----> ২ মার্চ, ২০২২
# বাংলাদেশ সরকারী কর্ম কমিশন কবে গঠিত হয়?
# ৬ এপ্রিল ১৯৭২
# ৭ এপ্রিল ১৯৭২
# ৮ এপ্রিল ১৯৭২
# ৯ এপ্রিল ১৯৭২
# ----> ৮ এপ্রিল ১৯৭২
# ‘e- TIN’ চালু করা হয় কত সালে?
# ২০১৩ সালে
# ২০১৪ সালে
# ২০১৫ সালে
# ২০১৬ সালে
# ----> ২০১৩ সালে
# কত সালে মানি লন্ডারিং প্রতিরোধ আইনটি প্রবর্তন করা হয়?
# ২০১১ সালে
# ২০১২ সালে
# ২০১৩ সালে
# ২০১৪ সালে
# ----> ২০১২ সালে
# দেশের কোন জেলায় সর্ববৃহৎ সৌরবিদ্যুৎ কেন্দ্র অবস্থিত?
# চট্টগ্রাম
# ফেনী
# নরসিংদী
# ময়মনসিংহ
# ----> ময়মনসিংহ
# বাংলাদেশে বন গবেষণা কেন্দ্র কোথায় অবস্থিত?
# রাজশাহী
# কুমিল্লা
# চট্টগ্রাম
# গাজীপুর
# ----> চট্টগ্রাম
# বাংলাদেশের মৎস্য প্রজাতি গবেষণাগার কোথায় অবস্থিত?
# চাঁদপুর
# ফরিদপুর
# ময়মনসিংহ
# ভোলা
# ----> ময়মনসিংহ
# বাংলাদেশের প্রধান খনিজ সম্পদ কোনটি?
# কয়লা
# প্রাকৃতিক গ্যাস
# চুনাপাথর
# চীনামাটি
# ----> প্রাকৃতিক গ্যাস
# ইউরিয়া সারের কাঁচামাল কী?
# প্রাকৃতিক গ্যাস
# চুনাপাথর
# মিথেন গ্যাস
# ইলমেনাইট
# ----> মিথেন গ্যাস
# কোনটি বিচার বিভাগের কাজ নয়?
# আইনের প্রয়োগ
# আইনের ব্যাখ্যা
# সংবিধানের ব্যাখ্যা
# সংবিধান প্রণয়ন
# ----> সংবিধান প্রণয়ন
# পারিবারিক আদালত অধ্যাদেশ কত সালে জারি হয়?
# ১৯৮০ সালে
# ১৯৮১ সালে
# ১৯৮৫ সালে
# ১৯৯১ সালে
# ----> ১৯৮৫ সালে
# ‘গণহত্যা যাদুঘর’ কোথায় অবস্থিত?
# ঢাকা
# চট্টগ্রাম
# কুমিল্লা
# খুলনা
# ----> খুলনা
# নভেরা আহমেদের পরিচয় কী হিসাবে?
# কবি
# নাট্যকার
# কণ্ঠশিল্পী
# ভাস্কর
# ----> ভাস্কর
# আয়তনে বাংলাদেশের সবচেয়ে বড় জেলা কোনটি?
# রাঙ্গামাটি
# বরিশাল
# চট্টগ্রাম
# ময়মনসিংহ
# ----> রাঙ্গামাটি
# কোন এলাকাকে ‘Marine Protected Area’ (MPA) ঘোষণা করা হয়েছে?
# সেন্টমার্টিন
# সেন্টমার্টিন এবং এর আশেপাশের এলাকা
# পটুয়াখালী ও বরগুনা
# হিরন পয়েন্ট
# ----> সেন্টমার্টিন এবং এর আশেপাশের এলাকা
# বাংলাদেশের ভৌগলিক নির্দেশক পণ্য কয়টি?
# ৯ (নয়) টি
# ১০ (দশ) টি
# ১১ (এগার) টি
# ১২ (বার) টি
# ----> ১১ (এগার) টি
# ক্ষুদ্র নৃ-গোষ্ঠী ‘মনিপুরী’ বাংলাদেশের কোন জেলায় বেশি বসবাস করে?
# সিলেট
# মৌলভীবাজার
# হবিগঞ্জ
# সুনামগঞ্জ
# ----> মৌলভীবাজার
# বাংলাদেশের ষষ্ঠ জাতীয় জনশুমারি ও গৃহ গণনা কোন সময়ে অনুষ্ঠিত হয়?
# ১০ জুন থেকে ১৬ জুন, ২০২২
# ১৫ জুন থেকে ২১ জুন, ২০২২
# ১৫ জুলাই থেকে ২১ জুলাই, ২০২২
# ২০ জুলাই থেকে ২৬ জুলাই, ২০২২
# ----> ১৫ জুন থেকে ২১ জুন, ২০২২
# কূটনৈতিক ক্ষেত্রে অবদানের জন্য গত ২০২০ সালে প্রবর্তিত পুরস্কারের নাম কী?
# বঙ্গবন্ধু ডিপ্লোমেটিক অ্যাওয়ার্ড ফর এক্সিলেন্স
# বঙ্গবন্ধু ডিপ্লোমেটিক এক্সিলেন্স অ্যাওয়ার্ড
# বাংলাদেশ ডিপ্লোমেটিক অ্যাওয়ার্ড ফর এক্সিলেন্স
# বঙ্গবন্ধু ডিপ্লোমেটিক অ্যাওয়ার্ড
# ----> বঙ্গবন্ধু ডিপ্লোমেটিক অ্যাওয়ার্ড ফর এক্সিলেন্স
# [{'question': 'She insisted on ––– leaving the house.', 'answer 1': 'he', 'answer 2': 'him', 'answer 3': 'himself', 'answer 4': 'his', 'correct_answer': 'his'}, {'question': 'The phrase “Achilles’ heel” means––', 'answer 1': 'a strong point', 'answer 2': 'a strong solution', 'answer 3': 'a weak point', 'answer 4': 'a permanent solution', 'correct_answer': 'a weak point'}, {'question': 'He does not adhere ––– any principle.', 'answer 1': 'by', 'answer 2': 'in', 'answer 3': 'at', 'answer 4': 'to', 'correct_answer': 'to'}, {'question': 'Millennium is a period of–––', 'answer 1': '100 year', 'answer 2': '1000 year', 'answer 3': '1 million year', 'answer 4': '1 million year', 'correct_answer': '1000 year'}, {'question': 'Identify the passive form of the following sentence : Who has broken this jug?', 'answer 1': 'By whom has this jug been broken?', 'answer 2': 'By whom has this jug broken?', 'answer 3': 'By whom this jug has been broken?', 'answer 4': 'Whom has this gug been broken?', 'correct_answer': 'By whom has this jug been broken?'}, {'question': 'Who is not a Victorian poet?', 'answer 1': 'Alfred Tennyson', 'answer 2': 'Robert Browning', 'answer 3': 'William Wordsworth', 'answer 4': 'Matthew Arnold', 'correct_answer': 'William Wordsworth'}, {'question': 'Which of the following novels was written by George Orwell?', 'answer 1': '1984―', 'answer 2': 'Brave\xa0New\xa0World―', 'answer 3': 'A\xa0clockwork\xa0Orange―', 'answer 4': 'For\xa0Whom\xa0the\xa0Bell\xa0Tolls―', 'correct_answer': '1984―'}, {'question': 'Identify the correct sentence:', 'answer 1': 'She speaks English like English', 'answer 2': 'She speaks the English like English', 'answer 3': 'She speaks the English like the English', 'answer 4': 'She speaks English like the English', 'correct_answer': 'She speaks English like the English'}, {'question': 'When one makes a promise, one must not go ––– on it.', 'answer 1': 'forward', 'answer 2': 'back', 'answer 3': 'by', 'answer 4': 'around', 'correct_answer': 'back'}, {'question': 'I\xa0can′t\xa0put\xa0up\xa0with―\xa0him\xa0any\xa0more.\xa0Here\xa0“put\xa0up\xa0with”\xa0means:', 'answer 1': 'To protect', 'answer 2': 'To terminate', 'answer 3': 'To tolerate', 'answer 4': 'To prevent', 'correct_answer': 'To tolerate'}, {'question': 'The poem “To his Coy Mistress” Was written by:', 'answer 1': 'Andrew Marvell', 'answer 2': 'John Donne', 'answer 3': 'George Herbert', 'answer 4': 'Henry Vaughan', 'correct_answer': 'Andrew Marvell'}, {'question': 'The synonyms of ‘altitude’ is–––', 'answer 1': 'height', 'answer 2': 'width', 'answer 3': 'length', 'answer 4': 'depth', 'correct_answer': 'height'}, {'question': 'The character, Elizabeth Bennett, appears in the novel––', 'answer 1': 'Pride\xa0and\xa0Prejudice―', 'answer 2': 'Tess\xa0of\xa0the\xa0D′llrberville―', 'answer 3': 'Wuthering\xa0Heights―', 'answer 4': 'Jane\xa0Eyre―', 'correct_answer': 'Pride\xa0and\xa0Prejudice―'}, {'question': 'This could have worked if I ____ been more far- sighted.', 'answer 1': 'have', 'answer 2': 'had', 'answer 3': 'might', 'answer 4': 'would', 'correct_answer': 'had'}, {'question': 'What\xa0may\xa0be\xa0considered\xa0courteous\xa0in\xa0one\xa0culture\xa0may\xa0be−arrogant―\xa0inanother.\xa0Here\xa0the\xa0underlined\xa0word\xa0“arrogant”\xa0means–––', 'answer 1': 'rude', 'answer 2': 'gracious', 'answer 3': 'coarse', 'answer 4': 'pretentious', 'correct_answer': 'rude'}, {'question': 'Don\xa0Juan―\xa0was\xa0composed\xa0by–––', 'answer 1': 'W B Yeats', 'answer 2': 'E.B. Browning', 'answer 3': 'George Gordon Byron', 'answer 4': 'Alexander Pope', 'correct_answer': 'George Gordon Byron'}, {'question': 'Identify the imperative sentence:', 'answer 1': 'Shut up!', 'answer 2': 'Shahin is playing football.', 'answer 3': 'I shall cook dinner now.', 'answer 4': 'What is your name?', 'correct_answer': 'Shut up!'}, {'question': '“Black Death” is the name of a ––', 'answer 1': 'fever', 'answer 2': 'black fever', 'answer 3': 'plague pandemic', 'answer 4': 'death of bla ...
