# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

plt.style.use('ggplot')

import nltk

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-748dd777-42bb-4eb1-a2c2-3fc58acb398e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-748dd777-42bb-4eb1-a2c2-3fc58acb398e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv("pysimplegui.csv")
df.head(140)
# print(df.shape)
# Out:
#                     User     Handle                  PostDate  \
# 0              Elon Musk  @elonmusk  2022-11-21T01:55:54.000Z
# 1              Elon Musk  @elonmusk  2022-11-21T01:19:15.000Z
# 2              Elon Musk  @elonmusk  2022-11-20T22:21:31.000Z
# 3              Elon Musk  @elonmusk  2022-11-20T14:40:09.000Z
# 4              Elon Musk  @elonmusk  2022-11-20T04:50:20.000Z
# ..                   ...        ...                       ...
# 135            Elon Musk  @elonmusk  2022-05-03T19:34:55.000Z
# 136  Elon Musk Retweeted     @Tesla  2022-05-03T04:20:53.000Z
# 137            Elon Musk  @elonmusk  2022-05-02T19:00:20.000Z
# 138            Elon Musk  @elonmusk  2022-05-02T18:12:19.000Z
# 139            Elon Musk  @elonmusk  2022-05-01T06:23:15.000Z
#
#                                              TweetText ReplyCount  \
# 0                              Our love will never die      16.2K
# 1                     And lead us not into temptation       47.8K
# ...

# %%
df['TweetText'].value_counts()
# Out:
# Elon Musk                                                                                                                                                                                                                                13
# Elon Musk-                                                                                                                                                                                                                                3
# What resolution is life in, 8k?                                                                                                                                                                                                           1
# This is where -the writers are,--Of past,-Present,-And Future                                                                                                                                                                             1
# ...

# %%
example=df['TweetText']
print(example)
# Out:
# 0                                Our love will never die
# 1                       And lead us not into temptation
# 2       Opening Ceremony-FIFA World Cup-World Cup Qat...
# 3      World Cup starts soon! Follow on Twitter for b...
# 4                                       twitter is ALIVE
#                              ...
# 141                 in case u need to lose a boner fast-
# 142                                What is best in life?
# 143                       The Barbarians are at the Gate
# 144                                Believe in the future
# 145                                            Elon Musk
# Name: TweetText, Length: 146, dtype: object

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
nltk.word_tokenize(str(example))

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
token=nltk.word_tokenize(str(example))
nltk.pos_tag(token)
# Out:
# [('0', 'CD'),
#  ('Our', 'PRP$'),
#  ('love', 'NN'),
#  ('will', 'MD'),
#  ('never', 'RB'),
#  ('die', 'VB'),
#  ('1', 'CD'),
#  ('And', 'CC'),
#  ('lead', 'VB'),
#  ('us', 'PRP'),
#  ('not', 'RB'),
#  ('into', 'IN'),
#  ('temptation', 'NN'),
#  ('2', 'CD'),
#  ('Opening', 'NNP'),
#  ('Ceremony-FIFA', 'JJ'),
#  ('World', 'NNP'),
#  ('Cup-World', 'NNP'),
#  ('Cup', 'NNP'),
#  ('Qat', 'NNP'),
#  ('...', ':'),
#  ('3', 'CD'),
#  ('World', 'NNP'),
#  ('Cup', 'NNP'),
#  ('starts', 'VBZ'),
#  ('soon', 'RB'),
#  ('!', '.'),
#  ('Follow', 'NNP'),
#  ('on', 'IN'),
#  ('Twitter', 'NNP'),
#  ('for', 'IN'),
#  ('b', 'NN'),
#  ('...', ':'),
#  ('4', 'CD'),
#  ('twitter', 'NN'),
#  ('is', 'VBZ'),
#  ('ALIVE', 'NNP'),
#  ('...', ':'),
#  ('141', 'CD'),
#  ('in', 'IN'),
#  ('case', 'NN'),
#  ('u', 'JJ'),
#  ('need', 'NN'),
#  ('to', 'TO'),
#  ('lose', 'VB'),
#  ('a', 'DT'),
#  ('boner', 'NN'),
#  ('fast-', 'JJ'),
#  ('142', 'CD'),
#  ('What', 'WP'),
#  ('is', 'VBZ'),
#  ('best', 'JJS'),
# ...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia=SentimentIntensityAnalyzer()

# %%
tweetlist=[]
for index, column in df.iterrows():
  print(column["TweetText"])
  tweetlist.append(column["TweetText"])

# %%
for tweetlist in example:
    ss = sid.polarity_scores(tweetlist) 
    print(ss)
# Out:
# {'neg': 0.0, 'neu': 0.29, 'pos': 0.71, 'compound': 0.8098}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6696}
# {'neg': 0.0, 'neu': 0.375, 'pos': 0.625, 'compound': 0.516}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.954, 'pos': 0.046, 'compound': 0.2263}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.4404}
# {'neg': 0.34, 'neu': 0.383, 'pos': 0.277, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.134, 'neu': 0.772, 'pos': 0.093, 'compound': -0.25}
# {'neg': 0.249, 'neu': 0.751, 'pos': 0.0, 'compound': -0.4574}
# ...
